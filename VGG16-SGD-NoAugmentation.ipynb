# %%
import os
import tensorflow as tf
from keras import layers
from keras import Model
from os import getcwd
from keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
from keras.optimizers import RMSprop
import keras
from keras.models import Sequential, Model
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, Dropout,GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD

# %%
model = keras.applications.VGG16(input_shape = (224, 224, 3), 
                                include_top = True, 
                                weights = 'imagenet')


for layer in model.layers:
    layer.trainable = False
    
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\joshi\Anaconda3\envs\tfcpu\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 0
# Non-trainable params: 138,357,544
# _________________________________________________________________

# %%
last_layer = model.get_layer('fc2')
last_output = last_layer.output

x = keras.layers.Dense(2,activation='softmax')(last_output)           

model = Model( model.input, x) 

model.compile(optimizer = SGD(lr=0.00001), 
              loss = 'binary_crossentropy', 
              metrics = ['acc'])

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 8,194
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
data_dir = "C:\\Users\\joshi\\OneDrive\\Desktop\\NIT Surat\\COVID-CT-master\\" # Your Dataset Location Path
train_dir = os.path.join(data_dir, 'Train')
val_dir = os.path.join(data_dir, 'Val')
train_malaria_dir = os.path.join(train_dir, 'COVID') #Replace the folder names
train_uninfected_dir = os.path.join(train_dir, 'NON-COVID')
validation_malaria_dir = os.path.join(val_dir, 'COVID')
validation_uninfected_dir = os.path.join(val_dir, 'NON-COVID')

train_malaria_fnames = os.listdir(train_malaria_dir)
train_uninfected_fnames = os.listdir(train_uninfected_dir)
validation_malaria_fnames = os.listdir(validation_malaria_dir)
validation_uninfected_fnames = os.listdir(validation_uninfected_dir)

print(len(train_malaria_fnames))
print(len(validation_malaria_fnames))
print(len(train_uninfected_fnames))
print(len(validation_uninfected_fnames))
# Out:
# 191
# 60
# 234
# 58

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   
                                   )


train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=8,
                                                    class_mode='categorical',
                                                    target_size=(224, 224)
                                                    )
validation_datagen = ImageDataGenerator(rescale=1./255)
 

validation_generator = validation_datagen.flow_from_directory(val_dir,
                                                              batch_size=8,
                                                              class_mode='categorical',
                                                              target_size=(224, 224))
# Out:
# Found 425 images belonging to 2 classes.
# Found 118 images belonging to 2 classes.

# %%
history = model.fit_generator(train_generator,
            validation_data = validation_generator,
            epochs = 100)
# Out:
# WARNING:tensorflow:From C:\Users\joshi\Anaconda3\envs\tfcpu\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\joshi\Anaconda3\envs\tfcpu\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 54/54 [==============================] - 103s 2s/step - loss: 1.2102 - acc: 0.4494 - val_loss: 0.8307 - val_acc: 0.5085
# Epoch 2/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.8522 - acc: 0.4494 - val_loss: 0.6867 - val_acc: 0.5085
# Epoch 3/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.7191 - acc: 0.4729 - val_loss: 0.7072 - val_acc: 0.5339
# Epoch 4/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.6851 - acc: 0.5459 - val_loss: 0.7319 - val_acc: 0.5339
# Epoch 5/100
# 54/54 [==============================] - 135s 3s/step - loss: 0.6724 - acc: 0.6047 - val_loss: 0.6263 - val_acc: 0.5508
# Epoch 6/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.6706 - acc: 0.6000 - val_loss: 0.7114 - val_acc: 0.5254
# Epoch 7/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6702 - acc: 0.6071 - val_loss: 0.5827 - val_acc: 0.5424
# Epoch 8/100
# 54/54 [==============================] - 141s 3s/step - loss: 0.6682 - acc: 0.6000 - val_loss: 0.7503 - val_acc: 0.5339
# Epoch 9/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6682 - acc: 0.5976 - val_loss: 0.6321 - val_acc: 0.5339
# Epoch 10/100
# 54/54 [==============================] - 138s 3s/step - loss: 0.6675 - acc: 0.6094 - val_loss: 0.7015 - val_acc: 0.5339
# Epoch 11/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.6695 - acc: 0.6000 - val_loss: 0.6680 - val_acc: 0.5339
# Epoch 12/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6720 - acc: 0.6118 - val_loss: 0.7067 - val_acc: 0.5424
# Epoch 13/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.6694 - acc: 0.6071 - val_loss: 0.7600 - val_acc: 0.5339
# Epoch 14/100
# 54/54 [==============================] - 134s 2s/step - loss: 0.6706 - acc: 0.6024 - val_loss: 0.7318 - val_acc: 0.5424
# Epoch 15/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.6688 - acc: 0.6094 - val_loss: 0.7237 - val_acc: 0.5424
# Epoch 16/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.6710 - acc: 0.6188 - val_loss: 0.6468 - val_acc: 0.5508
# Epoch 17/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.6735 - acc: 0.6188 - val_loss: 0.6735 - val_acc: 0.5339
# Epoch 18/100
# 54/54 [==============================] - 134s 2s/step - loss: 0.6693 - acc: 0.6188 - val_loss: 0.6849 - val_acc: 0.5424
# Epoch 19/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.6717 - acc: 0.6212 - val_loss: 0.6904 - val_acc: 0.5339
# Epoch 20/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6669 - acc: 0.6024 - val_loss: 0.6796 - val_acc: 0.5424
# Epoch 21/100
# 54/54 [==============================] - 145s 3s/step - loss: 0.6656 - acc: 0.6141 - val_loss: 0.6737 - val_acc: 0.5424
# Epoch 22/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6679 - acc: 0.6188 - val_loss: 0.7018 - val_acc: 0.5508
# Epoch 23/100
# 54/54 [==============================] - 138s 3s/step - loss: 0.6677 - acc: 0.6094 - val_loss: 0.7343 - val_acc: 0.5424
# Epoch 24/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6677 - acc: 0.6071 - val_loss: 0.6881 - val_acc: 0.5424
# Epoch 25/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6672 - acc: 0.6235 - val_loss: 0.6340 - val_acc: 0.5424
# Epoch 26/100
# 54/54 [==============================] - 138s 3s/step - loss: 0.6682 - acc: 0.6165 - val_loss: 0.7655 - val_acc: 0.5424
# Epoch 27/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6694 - acc: 0.6235 - val_loss: 0.6557 - val_acc: 0.5424
# Epoch 28/100
# 54/54 [==============================] - 143s 3s/step - loss: 0.6672 - acc: 0.6188 - val_loss: 0.7738 - val_acc: 0.5508
# Epoch 29/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.6687 - acc: 0.6235 - val_loss: 0.6542 - val_acc: 0.5508
# Epoch 30/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.6708 - acc: 0.6165 - val_loss: 0.6880 - val_acc: 0.5593
# Epoch 31/100
# 54/54 [==============================] - 141s 3s/step - loss: 0.6654 - acc: 0.6235 - val_loss: 0.7063 - val_acc: 0.5424
# Epoch 32/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.6668 - acc: 0.6141 - val_loss: 0.6976 - val_acc: 0.5508
# Epoch 33/100
# 54/54 [==============================] - 141s 3s/step - loss: 0.6659 - acc: 0.6259 - val_loss: 0.6835 - val_acc: 0.5424
# Epoch 34/100
# 54/54 [==============================] - 141s 3s/step - loss: 0.6689 - acc: 0.6306 - val_loss: 0.6623 - val_acc: 0.5593
# Epoch 35/100
# 54/54 [==============================] - 142s 3s/step - loss: 0.6669 - acc: 0.6118 - val_loss: 0.7544 - val_acc: 0.5593
# Epoch 36/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.6639 - acc: 0.6329 - val_loss: 0.6880 - val_acc: 0.5339
# Epoch 37/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.6685 - acc: 0.6259 - val_loss: 0.6225 - val_acc: 0.5508
# Epoch 38/100
# 54/54 [==============================] - 141s 3s/step - loss: 0.6640 - acc: 0.6188 - val_loss: 0.6939 - val_acc: 0.5508
# Epoch 39/100
# 54/54 [==============================] - 141s 3s/step - loss: 0.6613 - acc: 0.6235 - val_loss: 0.6630 - val_acc: 0.5508
# Epoch 40/100
# 54/54 [==============================] - 141s 3s/step - loss: 0.6637 - acc: 0.6282 - val_loss: 0.8001 - val_acc: 0.5508
# Epoch 41/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.6631 - acc: 0.6165 - val_loss: 0.7141 - val_acc: 0.5508
# Epoch 42/100
# 54/54 [==============================] - 136s 3s/step - loss: 0.6628 - acc: 0.6212 - val_loss: 0.6084 - val_acc: 0.5508
# Epoch 43/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.6605 - acc: 0.6071 - val_loss: 0.6990 - val_acc: 0.5424
# Epoch 44/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6684 - acc: 0.6353 - val_loss: 0.7907 - val_acc: 0.5508
# Epoch 45/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6624 - acc: 0.6306 - val_loss: 0.6457 - val_acc: 0.5593
# Epoch 46/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6663 - acc: 0.6353 - val_loss: 0.6697 - val_acc: 0.5508
# Epoch 47/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6677 - acc: 0.6353 - val_loss: 0.6127 - val_acc: 0.5678
# Epoch 48/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6653 - acc: 0.6329 - val_loss: 0.7073 - val_acc: 0.5593
# Epoch 49/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6600 - acc: 0.6306 - val_loss: 0.7631 - val_acc: 0.5593
# Epoch 50/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6609 - acc: 0.6306 - val_loss: 0.6649 - val_acc: 0.5508
# Epoch 51/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6621 - acc: 0.6212 - val_loss: 0.5853 - val_acc: 0.5508
# Epoch 52/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6602 - acc: 0.6212 - val_loss: 0.6390 - val_acc: 0.5424
# Epoch 53/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6588 - acc: 0.6329 - val_loss: 0.6596 - val_acc: 0.5508
# Epoch 54/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6603 - acc: 0.6306 - val_loss: 0.6690 - val_acc: 0.5508
# Epoch 55/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6596 - acc: 0.6141 - val_loss: 0.7087 - val_acc: 0.5508
# Epoch 56/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6569 - acc: 0.6141 - val_loss: 0.6963 - val_acc: 0.5508
# Epoch 57/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6614 - acc: 0.6259 - val_loss: 0.6460 - val_acc: 0.5508
# Epoch 58/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6637 - acc: 0.6376 - val_loss: 0.6834 - val_acc: 0.5678
# Epoch 59/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6599 - acc: 0.6282 - val_loss: 0.6896 - val_acc: 0.5763
# Epoch 60/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6637 - acc: 0.6188 - val_loss: 0.6794 - val_acc: 0.5763
# Epoch 61/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.6611 - acc: 0.6282 - val_loss: 0.6387 - val_acc: 0.5763
# Epoch 62/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6568 - acc: 0.6329 - val_loss: 0.7246 - val_acc: 0.5763
# Epoch 63/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6587 - acc: 0.6329 - val_loss: 0.7038 - val_acc: 0.5508
# Epoch 64/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6601 - acc: 0.6329 - val_loss: 0.6699 - val_acc: 0.5508
# Epoch 65/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6582 - acc: 0.6329 - val_loss: 0.6230 - val_acc: 0.5508
# Epoch 66/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6558 - acc: 0.6376 - val_loss: 0.6269 - val_acc: 0.5508
# Epoch 67/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6564 - acc: 0.6306 - val_loss: 0.6450 - val_acc: 0.5508
# Epoch 68/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6615 - acc: 0.6447 - val_loss: 0.5832 - val_acc: 0.5508
# Epoch 69/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6585 - acc: 0.6400 - val_loss: 0.5431 - val_acc: 0.5508
# Epoch 70/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6565 - acc: 0.6400 - val_loss: 0.6422 - val_acc: 0.5508
# Epoch 71/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6563 - acc: 0.6353 - val_loss: 0.6797 - val_acc: 0.5593
# Epoch 72/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.6570 - acc: 0.6353 - val_loss: 0.7603 - val_acc: 0.5508
# Epoch 73/100
# 54/54 [==============================] - 134s 2s/step - loss: 0.6573 - acc: 0.6376 - val_loss: 0.6626 - val_acc: 0.5763
# Epoch 74/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6535 - acc: 0.6353 - val_loss: 0.6744 - val_acc: 0.5508
# Epoch 75/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.6552 - acc: 0.6282 - val_loss: 0.6494 - val_acc: 0.5508
# Epoch 76/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6547 - acc: 0.6376 - val_loss: 0.7107 - val_acc: 0.5508
# Epoch 77/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6597 - acc: 0.6424 - val_loss: 0.7242 - val_acc: 0.5763
# Epoch 78/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6559 - acc: 0.6400 - val_loss: 0.7456 - val_acc: 0.5847
# Epoch 79/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6567 - acc: 0.6376 - val_loss: 0.7424 - val_acc: 0.5847
# Epoch 80/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6548 - acc: 0.6518 - val_loss: 0.6860 - val_acc: 0.5847
# Epoch 81/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6539 - acc: 0.6329 - val_loss: 0.6323 - val_acc: 0.5593
# Epoch 82/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6575 - acc: 0.6565 - val_loss: 0.7046 - val_acc: 0.5763
# Epoch 83/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6534 - acc: 0.6471 - val_loss: 0.6374 - val_acc: 0.5508
# Epoch 84/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6526 - acc: 0.6471 - val_loss: 0.6062 - val_acc: 0.5508
# Epoch 85/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6561 - acc: 0.6447 - val_loss: 0.7099 - val_acc: 0.5678
# Epoch 86/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6573 - acc: 0.6494 - val_loss: 0.7173 - val_acc: 0.5678
# Epoch 87/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6537 - acc: 0.6376 - val_loss: 0.5891 - val_acc: 0.5508
# Epoch 88/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6571 - acc: 0.6541 - val_loss: 0.6981 - val_acc: 0.5508
# Epoch 89/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.6531 - acc: 0.6471 - val_loss: 0.6694 - val_acc: 0.5593
# Epoch 90/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6592 - acc: 0.6282 - val_loss: 0.7117 - val_acc: 0.5763
# Epoch 91/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6586 - acc: 0.6541 - val_loss: 0.7071 - val_acc: 0.5932
# Epoch 92/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6517 - acc: 0.6518 - val_loss: 0.5945 - val_acc: 0.5508
# Epoch 93/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6530 - acc: 0.6541 - val_loss: 0.7343 - val_acc: 0.5847
# Epoch 94/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6528 - acc: 0.6541 - val_loss: 0.6205 - val_acc: 0.5763
# Epoch 95/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6527 - acc: 0.6471 - val_loss: 0.6314 - val_acc: 0.5847
# Epoch 96/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6538 - acc: 0.6471 - val_loss: 0.7786 - val_acc: 0.5932
# Epoch 97/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6559 - acc: 0.6565 - val_loss: 0.6349 - val_acc: 0.5932
# Epoch 98/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6531 - acc: 0.6424 - val_loss: 0.7461 - val_acc: 0.5678
# Epoch 99/100
# 54/54 [==============================] - 130s 2s/step - loss: 0.6541 - acc: 0.6518 - val_loss: 0.7762 - val_acc: 0.5763
# Epoch 100/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.6515 - acc: 0.6471 - val_loss: 0.7352 - val_acc: 0.5932

# %%
test_dir = os.path.join(data_dir, 'Test')
test_malaria_dir = os.path.join(test_dir, 'COVID') #Replace the folder names
test_uninfected_dir = os.path.join(test_dir, 'NON-COVID')
test_malaria_fnames = os.listdir(test_malaria_dir)
test_uninfected_fnames = os.listdir(test_uninfected_dir)
print(len(test_malaria_fnames))
print(len(test_uninfected_fnames))
# Out:
# 98
# 105

# %%
testGenerator = ImageDataGenerator().flow_from_directory(test_dir, 
                                                      batch_size=8,
                                                    class_mode='categorical',shuffle=False,target_size=(224,224)
                                                      )
# Out:
# Found 203 images belonging to 2 classes.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix,classification_report
batch_size = 8
num_of_test_samples = 203
predictions = model.predict_generator(testGenerator)

y_pred = np.argmax(predictions, axis=1)

true_classes = testGenerator.classes

class_labels = list(testGenerator.class_indices.keys())   

print(class_labels)

print(confusion_matrix(testGenerator.classes, y_pred))

report = classification_report(true_classes, y_pred, target_names=class_labels)
print(report)
# Out:
# ['COVID', 'NON-COVID']
# [[30 68]
#  [15 90]]
#               precision    recall  f1-score   support
#
#        COVID       0.67      0.31      0.42        98
#    NON-COVID       0.57      0.86      0.68       105
#
#     accuracy                           0.59       203
#    macro avg       0.62      0.58      0.55       203
# weighted avg       0.62      0.59      0.56       203

# %%
from sklearn import metrics
metrics.roc_auc_score(y_pred, testGenerator.classes)
# Out:
# 0.6181434599156119

# %%
metrics.accuracy_score(testGenerator.classes, y_pred)
# Out:
# 0.5911330049261084
