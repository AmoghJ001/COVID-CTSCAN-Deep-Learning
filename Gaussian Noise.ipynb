# %%
import skimage.io
import matplotlib.pyplot as plt

# %%
# %cd C:\Users\joshi\OneDrive\Desktop\NIT Surat\COVID-CT-master\Data\Train\COVID\noise
# Out:
# C:\Users\joshi\OneDrive\Desktop\NIT Surat\COVID-CT-master\Data\Train\COVID\noise

# %%
plt.subplot(1,2,1)
img_path1="C:\\Users\\joshi\\OneDrive\\Desktop\\NIT Surat\\COVID-CT-master\\Data\\Train\\COVID\\2020.02.11.20022053-p12-67%3.png"
img1 = skimage.io.imread(img_path1)
skimage.io.imshow(img)
plt.title('Original Image')
plt.subplot(1,2,2)
img_path="noise_29.png"
img = skimage.io.imread(img_path)
skimage.io.imshow(img)
plt.title('With Gaussian Noise')
# Out:
# Text(0.5, 1.0, 'With Gaussian Noise')
